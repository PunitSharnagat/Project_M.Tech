# %% [markdown]
# # Evolution of urban patterns: urban morphology as an open reproducible data science
#
# ## Summary statistics
#
# This is the second notebook in a sequence of three. The notebook summarise morphometric data obtained in the previous notebook on the basis of historical periods.
#
# It requires `data/case_studies.csv` input with origins of case studies and data generated by the first notebook.
#
# Date: May 17, 2021
#
# ---
#
# We start with the import of libraries used in this notebook.

# %%
import pandas as pd
import seaborn as sns
from shapely.geometry import Point
import geopandas as gpd
import matplotlib.pyplot as plt
import glob
import pathlib
from palettable.wesanderson import Moonrise5_6

# %% [markdown]
# Using seaborn we can specify global settings for all matplotlib-based plots.

# %%
sns.set()

# %% [markdown]
# We will need the original input of our case studies as we needed in the first notebook.

# %%
cases = pd.read_csv("data/case_studies3.csv")
cases
# Out:
#                                       case           period  \
# 0                          Connaught Place   pre-industrial
# 1                              Nehru Place   pre-industrial
# 2                               Baner gaon   pre-industrial
# 3                                Siripuram   pre-industrial
# 4                                Manikonda   pre-industrial
# 5                                  T Nagar   pre-industrial
# 6                             Cuffe Parade   pre-industrial
# 7                           Ballard Estate   pre-industrial
# 8                              Indiranagar       industrial
# 9                          Electronic City       industrial
# 10                           Nariman Point       industrial
# 11                    Bandra Kurla Complex       industrial
# 12                             Koramangala       industrial
# 13                                   Bardi       industrial
# 14                              Gachibowli       industrial
# 15                                   Abids       industrial
# 16  Gujarat International Finance Tec-City        modernist
# 17                               Sector 17        modernist
# 18                             Gandhipuram        modernist
# 19                              Nagar Road        modernist
# 20                             Viman nagar        modernist
# 21                              HITEC City        modernist
# 22                                 MG road        modernist
# 23                                Nampally      garden city
# 24                            Nanakramguda      garden city
# 25                               East Fort      garden city
# 26                            Daba Gardens      garden city
# 27                           Yerwada Nagar      garden city
# 28                            Shivajinagar  neo-traditional
# 29                           Bangalore CBD  neo-traditional
# 30                             CBD Belapur  neo-traditional
# 31                              Anna Salai  neo-traditional
# 32             Parry's Corner, George Town  neo-traditional
# 33                            Nungambakkam  neo-traditional
# 34                           Dwaraka Nagar  neo-traditional
# 35                         Deccan Gymkhana         informal
# 36                             Vijay Nagar         informal
# 37                                RS Puram         informal
# 38                             City Centre         informal
#
#                                      origin
# 0     (77.2194442012068, 28.63264672036609)
# 1    (77.25246542282517, 28.54930101761747)
# 2   (73.78743391399972, 18.559120436182322)
# 3   (83.31672292288425, 17.719918874948867)
# 4   (78.37094172770058, 17.411693315316967)
# 5   (80.23817967215369, 13.043225604625261)
# 6    (72.82000253375675, 18.91442395337802)
# 7   (72.83688268053827, 18.936504427534746)
# 8   (77.64059073182727, 12.975796346358312)
# 9   (77.67473906976637, 12.836071363558153)
# 10  (72.82480722132986, 18.925214568881227)
# 11   (72.8627395804263, 19.066314041680574)
# 12  (77.62422481701566, 12.932468918052901)
# 13  (79.10458907116659, 21.113643527802385)
# 14  (78.34181221690613, 17.439597387369282)
# 15  (78.47305487958732, 17.392477263206835)
# 16   (72.67485981593542, 23.16744269468325)
# 17   (76.78290491251747, 30.74032703365866)
# 18  (76.96709432544513, 11.017985864822265)
# 19  (73.93671275054801, 18.552918615853407)
# 20  (73.91370983261332, 18.569540936145668)
# 21    (78.37642539488179, 17.4472932673904)
# 22   (76.28737320606601, 9.965235248299617)
# 23   (78.46706031927066, 17.38536969509493)
# 24  (78.34206832738829, 17.414652501695837)
# 25   (76.94694500055203, 8.484209479184205)
# 26   (83.29578043954257, 17.71494253659769)
# 27   (73.88371376101495, 18.55895076622647)
# 28  (77.60414560872263, 12.985514528680847)
# 29  (77.61384973745103, 12.972983423750193)
# 30   (73.03629797764636, 19.02250701461816)
# 31   (80.24836498997554, 13.04264949806235)
# 32   (80.28807224465172, 13.08984009459016)
# 33  (80.23990999833575, 13.062126212975132)
# 34  (83.30887891367962, 17.730219344458725)
# 35   (73.8364547266035, 18.516500373211034)
# 36  (75.89350662379711, 22.754221775822128)
# 37   (76.95129816033725, 11.00858011567008)
# 38  (86.14787941191288, 23.667200105645797)

# %% [markdown]
# It will be easier to use `case` column as an index.

# %%
cases = cases.set_index("case")

# %% [markdown]
# Using `glob` library, we get a list of all GeoPackages created in the first notebook.

# %%
files = glob.glob("data/*gpkg")

# %% [markdown]
# We need to generate a single DataFrame with all the results of all case studies combined. Let's prepare an empty DataFrame for that.

# %%
data = pd.DataFrame()

# %% [markdown]
# Now we loop through the list of GeoPackages and:
# 1. Read the file.
# 2. Select only those geometries within 400 m buffer around the origin. That way we minimise potential edge effect affecting the results.
# 3. Store period and case name within the DataFrame and append it together with morphometric data from GPKG to our `data` DataFrame.

# %%
for f in files:
    tessellation = gpd.read_file(f, layer="tessellation")
    case = pathlib.Path(f).stem
    coords = cases.origin.loc[case]
    buffer = gpd.GeoSeries([Point(tuple(map(float, coords[1:-1].split(', '))))], crs=4326).to_crs(tessellation.crs).buffer(400)
    tessellation['period'] = cases.period.loc[case]
    tessellation['case'] = case
    casegdf = tessellation[tessellation.centroid.within(buffer.iloc[0])]
    data = data.append(casegdf.drop(columns=["uID", "nID", "mm_len", "node_start", "node_end", "nodeID", "geometry"]))

# %% [markdown]
# Since `period` is an ordered categorical column, let's encode it as such.

# %%
data['period'] = pd.Categorical(data['period'], categories=['pre-industrial', 'industrial', 'garden city', 'modernist', 'neo-traditional', 'informal'], ordered=True)

# %% [markdown]
# Now we can sort the `data` based on the `period` in a way which follows the time.

# %%
data = data.sort_values('period').reset_index(drop=True)

# %% [markdown]
# For our figures, we want `paper` context, `whitegrid` style and `palettable`'s `Moonrise5_6` color palette.

# %%
sns.set_context("paper")
sns.set_style("whitegrid")
sns.set_palette(Moonrise5_6.hex_colors)

# %% [markdown]
# It is better to rename final labels to nicers ones, so let's prepare a dictionary for that.

# %%
labels = {
    "cell_area": "Area of a tessellation cell [m]",
    "car": "Covered area ratio",
    "blg_area": "Area of a building footprint [m]",
    "wall": "Length of a perimeter wall [m]",
    "adjacency": "Building adjacency",
    "neighbour_distance": "Mean neighbor distance between buildings [m]",
    "length": "Length of a street segment [m]",
    "linearity": "Linearity of a street segment",
    "width": "Width of a street profile [m]",
    "width_deviation": "Width deviation of a street profile [m]",
    "openness": "Openness of a street profile",
    "meshedness": "Meshedness of a street network",
}

# %% [markdown]
# Now we loop through all morphometric characters and create box plots for each city, once with normal y axis and once with log y axis.

# %%
for ch in data.columns.drop(['case', 'period']):
    plt.figure(figsize=(12, 8))
    boxen = sns.boxplot(x="case", y=ch, hue='period', dodge=False, data=data, showfliers=False)
    boxen.set_xticklabels(boxen.get_xticklabels(), rotation=90)
    boxen.set_ylabel(labels[ch])
    boxen.set_xlabel("Case study")
    sns.despine()
    plt.legend(loc="lower left", borderaxespad=0., ncol=6, frameon=False)
    plt.savefig(f"figures/{ch}_all_normal.png", bbox_inches="tight")
    plt.close("all")
    
    plt.figure(figsize=(12, 8))
    boxen = sns.boxplot(x="case", y=ch, hue='period', dodge=False, data=data, showfliers=False)
    boxen.set_xticklabels(boxen.get_xticklabels(), rotation=90)
    boxen.set_ylabel(labels[ch])
    boxen.set_xlabel("Case study")
    boxen.set_yscale("log")
    sns.despine()
    plt.legend(loc="lower left", borderaxespad=0., ncol=6, frameon=False)
    plt.savefig(f"figures/{ch}_all_log.png", bbox_inches="tight")
    plt.close("all")

# %% [markdown]
# We can also create box plots for each character grouped by period.

# %%
for ch in data.columns.drop(['case', 'period']):
    plt.figure(figsize=(12, 8))
    box = sns.boxplot(x="period", y=ch,dodge=False, data=data, showfliers=False)
    box.set_ylabel(labels[ch])
    box.set_xlabel("Historical period")
    sns.despine()
    plt.savefig(f"figures/{ch}_grouped_normal.png", bbox_inches="tight")
    plt.close("all")
    
    plt.figure(figsize=(12, 8))
    box = sns.boxplot(x="period", y=ch,dodge=False, data=data, showfliers=False)
    box.set_ylabel(labels[ch])
    box.set_xlabel("Historical period")
    box.set_yscale("log")
    sns.despine()
    plt.savefig(f"figures/{ch}_grouped_log.png", bbox_inches="tight")
    plt.close("all")

# %% [markdown]
# To report median values per character and period, we can create a grouped DataFrame.

# %%
grouper = data.drop(columns='case').groupby('period')
medians = grouper.median()
medians = medians.rename(columns=labels)
med = medians.T.round(2)
med
# Out:
# period                                        pre-industrial  industrial  \
# Area of a tessellation cell [m]                      1042.56      404.37
# Covered area ratio                                      0.27        0.39
# Area of a building footprint [m]                      260.71      155.19
# Length of a perimeter wall [m]                         70.80       51.68
# Building adjacency                                      1.00        1.00
# Mean neighbor distance between buildings [m]           15.85        8.09
# Length of a street segment [m]                        128.54      119.95
# Linearity of a street segment                           1.00        1.00
# Width of a street profile [m]                          22.99       16.75
# Width deviation of a street profile [m]                 3.87        4.51
# Openness of a street profile                            0.47        0.29
# Meshedness of a street network                          0.16        0.14
#
# period                                        garden city  modernist  \
# Area of a tessellation cell [m]                    644.40     435.06
# Covered area ratio                                   0.20       0.35
# Area of a building footprint [m]                   115.04     139.38
# Length of a perimeter wall [m]                      44.44      49.07
# Building adjacency                                   1.00       1.00
# Mean neighbor distance between buildings [m]        13.95      10.16
# Length of a street segment [m]                      95.04     108.34
# Linearity of a street segment                        1.00       1.00
# Width of a street profile [m]                       20.48      13.73
# Width deviation of a street profile [m]              5.01       4.25
# Openness of a street profile                         0.57       0.36
# Meshedness of a street network                       0.14       0.11
#
# period                                        neo-traditional  informal
# Area of a tessellation cell [m]                        404.51    493.61
# Covered area ratio                                       0.31      0.33
# Area of a building footprint [m]                       122.24    153.97
# Length of a perimeter wall [m]                          46.93     52.01
# Building adjacency                                       1.00      1.00
# Mean neighbor distance between buildings [m]             8.31     10.63
# Length of a street segment [m]                         107.40     85.84
# Linearity of a street segment                            1.00      1.00
# Width of a street profile [m]                           16.82     18.84
# Width deviation of a street profile [m]                  5.27      4.50
# Openness of a street profile                             0.35      0.39
# Meshedness of a street network                           0.17      0.17

# %% [markdown]
# It may also be useful to report interquartile range to illustrate the spread of each distribution.

# %%
iqr = (grouper.quantile(.75).values - grouper.quantile(.25))
iqr = iqr.rename(columns=labels)
iq = iqr.T.round(2)
iq
# Out:
# period                                        pre-industrial  industrial  \
# Area of a tessellation cell [m]                      1733.99      554.94
# Covered area ratio                                      0.24        0.21
# Area of a building footprint [m]                      342.44      175.11
# Length of a perimeter wall [m]                         55.03       29.48
# Building adjacency                                      0.02        0.00
# Mean neighbor distance between buildings [m]           16.49        7.43
# Length of a street segment [m]                        128.96      104.16
# Linearity of a street segment                           0.01        0.00
# Width of a street profile [m]                          13.89        9.64
# Width deviation of a street profile [m]                 2.51        2.45
# Openness of a street profile                            0.27        0.20
# Meshedness of a street network                          0.07        0.07
#
# period                                        garden city  modernist  \
# Area of a tessellation cell [m]                    976.49     951.03
# Covered area ratio                                   0.21       0.28
# Area of a building footprint [m]                   152.79     118.44
# Length of a perimeter wall [m]                      29.44      68.39
# Building adjacency                                   0.00       0.01
# Mean neighbor distance between buildings [m]        16.30      25.54
# Length of a street segment [m]                      61.16      87.62
# Linearity of a street segment                        0.01       0.00
# Width of a street profile [m]                       17.28      13.50
# Width deviation of a street profile [m]              3.12       2.94
# Openness of a street profile                         0.30       0.44
# Meshedness of a street network                       0.07       0.07
#
# period                                        neo-traditional  informal
# Area of a tessellation cell [m]                        863.87    660.08
# Covered area ratio                                       0.22      0.20
# Area of a building footprint [m]                       212.40    121.47
# Length of a perimeter wall [m]                          39.87     18.86
# Building adjacency                                       0.00      0.00
# Mean neighbor distance between buildings [m]            11.17      9.35
# Length of a street segment [m]                         104.53     78.39
# Linearity of a street segment                            0.01      0.00
# Width of a street profile [m]                           10.62      7.34
# Width deviation of a street profile [m]                  1.95      2.80
# Openness of a street profile                             0.30      0.19
# Meshedness of a street network                           0.05      0.03

# %% [markdown]
# We want to report both in the same table.

# %%
med.astype('str') + ' (' + iq.astype('str') + ')'
# Out:
# period                                           pre-industrial  \
# Area of a tessellation cell [m]               1042.56 (1733.99)
# Covered area ratio                                  0.27 (0.24)
# Area of a building footprint [m]                260.71 (342.44)
# Length of a perimeter wall [m]                     70.8 (55.03)
# Building adjacency                                   1.0 (0.02)
# Mean neighbor distance between buildings [m]      15.85 (16.49)
# Length of a street segment [m]                  128.54 (128.96)
# Linearity of a street segment                        1.0 (0.01)
# Width of a street profile [m]                     22.99 (13.89)
# Width deviation of a street profile [m]             3.87 (2.51)
# Openness of a street profile                        0.47 (0.27)
# Meshedness of a street network                      0.16 (0.07)
#
# period                                             industrial  \
# Area of a tessellation cell [m]               404.37 (554.94)
# Covered area ratio                                0.39 (0.21)
# Area of a building footprint [m]              155.19 (175.11)
# Length of a perimeter wall [m]                  51.68 (29.48)
# Building adjacency                                  1.0 (0.0)
# Mean neighbor distance between buildings [m]      8.09 (7.43)
# Length of a street segment [m]                119.95 (104.16)
# Linearity of a street segment                       1.0 (0.0)
# Width of a street profile [m]                    16.75 (9.64)
# Width deviation of a street profile [m]           4.51 (2.45)
# Openness of a street profile                       0.29 (0.2)
# Meshedness of a street network                    0.14 (0.07)
#
# period                                            garden city  \
# Area of a tessellation cell [m]                644.4 (976.49)
# Covered area ratio                                 0.2 (0.21)
# Area of a building footprint [m]              115.04 (152.79)
# Length of a perimeter wall [m]                  44.44 (29.44)
# Building adjacency                                  1.0 (0.0)
# Mean neighbor distance between buildings [m]     13.95 (16.3)
# Length of a street segment [m]                  95.04 (61.16)
# Linearity of a street segment                      1.0 (0.01)
# Width of a street profile [m]                   20.48 (17.28)
# Width deviation of a street profile [m]           5.01 (3.12)
# Openness of a street profile                       0.57 (0.3)
# Meshedness of a street network                    0.14 (0.07)
#
# period                                              modernist  \
# Area of a tessellation cell [m]               435.06 (951.03)
# Covered area ratio                                0.35 (0.28)
# Area of a building footprint [m]              139.38 (118.44)
# Length of a perimeter wall [m]                  49.07 (68.39)
# Building adjacency                                 1.0 (0.01)
# Mean neighbor distance between buildings [m]    10.16 (25.54)
# Length of a street segment [m]                 108.34 (87.62)
# Linearity of a street segment                       1.0 (0.0)
# Width of a street profile [m]                    13.73 (13.5)
# Width deviation of a street profile [m]           4.25 (2.94)
# Openness of a street profile                      0.36 (0.44)
# Meshedness of a street network                    0.11 (0.07)
#
# period                                        neo-traditional         informal
# Area of a tessellation cell [m]               404.51 (863.87)  493.61 (660.08)
# Covered area ratio                                0.31 (0.22)       0.33 (0.2)
# Area of a building footprint [m]               122.24 (212.4)  153.97 (121.47)
# Length of a perimeter wall [m]                  46.93 (39.87)    52.01 (18.86)
# Building adjacency                                  1.0 (0.0)        1.0 (0.0)
# Mean neighbor distance between buildings [m]     8.31 (11.17)     10.63 (9.35)
# Length of a street segment [m]                 107.4 (104.53)    85.84 (78.39)
# Linearity of a street segment                      1.0 (0.01)        1.0 (0.0)
# Width of a street profile [m]                   16.82 (10.62)     18.84 (7.34)
# Width deviation of a street profile [m]           5.27 (1.95)        4.5 (2.8)
# Openness of a street profile                       0.35 (0.3)      0.39 (0.19)
# Meshedness of a street network                    0.17 (0.05)      0.17 (0.03)

# %% [markdown]
# Following cells pick individual boxplots (same we created above) and generate combined figures used in the final paper.

# %%
fig = plt.figure(figsize=(8, 7), constrained_layout=True)
gs = fig.add_gridspec(6, 2)
top = fig.add_subplot(gs[0:4, :])
left = fig.add_subplot(gs[4:, 0])
right = fig.add_subplot(gs[4:, 1])

sns.boxplot(x="case", y='neighbour_distance', hue='period', dodge=False, data=data, showfliers=False, ax=top, linewidth=.75)
top.set_xticklabels(top.get_xticklabels(), rotation=90)
top.set_ylabel(labels['neighbour_distance'])
top.set_xlabel("")

sns.boxplot(x="period", y='cell_area',dodge=False, data=data, showfliers=False, ax=left, linewidth=.75)
left.set_ylabel(labels['cell_area'])
left.set_xlabel("Historical period")
left.set_xticklabels(left.get_xticklabels(), rotation=90)
left.set_yscale("log")

sns.boxplot(x="period", y='blg_area',dodge=False, data=data, showfliers=False, ax=right, linewidth=.75)
right.set_ylabel(labels['blg_area'])
right.set_xlabel("Historical period")
right.set_xticklabels(right.get_xticklabels(), rotation=90)
right.set_yscale("log")
sns.despine()

top.legend(loc="upper left", borderaxespad=0., ncol=3, frameon=True)
plt.savefig(f"figures/results_1.png", bbox_inches="tight", dpi=300)

# %%
fig = plt.figure(figsize=(8, 7), constrained_layout=True)
gs = fig.add_gridspec(6, 2)
top = fig.add_subplot(gs[0:4, :])
left = fig.add_subplot(gs[4:, 0])
right = fig.add_subplot(gs[4:, 1])

sns.boxplot(x="case", y='openness', hue='period', dodge=False, data=data, showfliers=False, ax=top, linewidth=.75)
top.set_xticklabels(top.get_xticklabels(), rotation=90)
top.set_ylabel(labels['openness'])
top.set_xlabel("")

sns.boxplot(x="period", y='car',dodge=False, data=data, showfliers=False, ax=left, linewidth=.75)
left.set_ylabel(labels['car'])
left.set_xlabel("Historical period")
left.set_xticklabels(left.get_xticklabels(), rotation=90)
left.set_yscale("log")

sns.boxplot(x="period", y='width',dodge=False, data=data, showfliers=False, ax=right, linewidth=.75)
right.set_ylabel(labels['width'])
right.set_xlabel("Historical period")
right.set_xticklabels(right.get_xticklabels(), rotation=90)
right.set_yscale("log")
sns.despine()

top.legend(loc="upper left", borderaxespad=0., ncol=3, frameon=True)
plt.savefig(f"figures/results_2.png", bbox_inches="tight", dpi=300)

# %%
fig = plt.figure(figsize=(8, 3), constrained_layout=True)
gs = fig.add_gridspec(1, 2)
left = fig.add_subplot(gs[0, 0])
right = fig.add_subplot(gs[0, 1])

sns.boxplot(x="period", y='wall',dodge=False, data=data, showfliers=False, ax=left, linewidth=.75)
left.set_ylabel(labels['wall'])
left.set_xlabel("Historical period")
left.set_xticklabels(left.get_xticklabels(), rotation=90)

sns.boxplot(x="period", y='adjacency',dodge=False, data=data, showfliers=False, ax=right, linewidth=.75)
right.set_ylabel(labels['adjacency'])
right.set_xlabel("Historical period")
right.set_xticklabels(right.get_xticklabels(), rotation=90)
sns.despine()

plt.savefig(f"figures/results_3.png", bbox_inches="tight", dpi=300)

# %%
fig = plt.figure(figsize=(8, 7), constrained_layout=True)
gs = fig.add_gridspec(6, 2)
top = fig.add_subplot(gs[0:4, :])
left = fig.add_subplot(gs[4:, 0])
right = fig.add_subplot(gs[4:, 1])

sns.boxplot(x="case", y='meshedness', hue='period', dodge=False, data=data, showfliers=False, ax=top, linewidth=.75)
top.set_xticklabels(top.get_xticklabels(), rotation=90)
top.set_ylabel(labels['meshedness'])
top.set_xlabel("")

sns.boxplot(x="period", y='linearity',dodge=False, data=data, showfliers=False, ax=left, linewidth=.75)
left.set_ylabel(labels['linearity'])
left.set_xlabel("Historical period")
left.set_xticklabels(left.get_xticklabels(), rotation=90)

sns.boxplot(x="period", y='width_deviation',dodge=False, data=data, showfliers=False, ax=right, linewidth=.75)
right.set_ylabel(labels['width_deviation'])
right.set_xlabel("Historical period")
right.set_xticklabels(right.get_xticklabels(), rotation=90)
sns.despine()

top.legend(loc="upper right", borderaxespad=0., ncol=3, frameon=True)
plt.savefig(f"figures/results_4.png", bbox_inches="tight", dpi=300)

# %% [markdown]
# ## Statistical comparison
#
# We also want to compare similarity of distributions statistically, not only visually. We use Kruskal–Wallis one-way analysis of variance and Pairwise Mann–Whitney *U* test for that.

# %%
from scipy import stats

data = data.set_index('case')

# %%
data = data.rename(columns=labels)

# %% [markdown]
# ### Kruskal–Wallis one-way analysis of variance
#
# Kruskal–Wallis one-way analysis of variance is chosen as a non-parametric equivalent of ANOVA due to skewed distributions of underlying data.

# %%
kruskal = pd.DataFrame()
for col in data.columns.drop("period"):
    H, p = stats.kruskal(*[data[data.period == per][col] for per in data.period.cat.categories])
    kruskal.loc[col, 'H'] = H
    kruskal.loc[col, 'p'] = p

# %%
kruskal
# Out:
#                                                         H              p
# Area of a tessellation cell [m]                917.811332  3.716801e-196
# Covered area ratio                             855.631002  1.063798e-182
# Area of a building footprint [m]               696.186732  3.279061e-148
# Length of a perimeter wall [m]                 704.013755  6.658790e-150
# Building adjacency                             848.964970  2.946364e-181
# Mean neighbor distance between buildings [m]   814.156865  1.001298e-173
# Length of a street segment [m]                 331.724076   1.502928e-69
# Linearity of a street segment                  390.765691   2.899557e-82
# Width of a street profile [m]                  721.149510  1.312308e-153
# Width deviation of a street profile [m]        696.868079  2.335781e-148
# Openness of a street profile                  1308.135099  1.103737e-280
# Meshedness of a street network                1407.013667  4.159644e-302

# %% [markdown]
# The results indicate that the distributions of morphometric values obtained from samples from different historical periods cannot be considered the same.

# %% [markdown]
# ### Pairwise Mann–Whitney _U_ test

# %%
from itertools import product

mann_whitney_U = {}
mann_whitney_p = {}
for col in data.columns.drop("period"):
    df_u = pd.DataFrame(columns=data.period.cat.categories, index=data.period.cat.categories)
    df_p = pd.DataFrame(columns=data.period.cat.categories, index=data.period.cat.categories)
    for a, b in product(data.period.cat.categories, repeat=2):
        if pd.isna(df_u.loc[b, a]):
            U, p = stats.mannwhitneyu(data[data.period == a][col], data[data.period == b][col])
            df_u.loc[a, b] = U
            df_p.loc[a, b] = p
        else:
            df_u.loc[a, b] = df_u.loc[b, a]
            df_p.loc[a, b] = df_p.loc[b, a]
            
    mann_whitney_U[col] = df_u
    mann_whitney_p[col] = df_p

# %%
for col in data.columns.drop("period"):
    if not (mann_whitney_p[col] > .05).sum().sum() == 6:
        print(f"{col}")
# Out:
# Area of a tessellation cell [m]
# Covered area ratio
# Area of a building footprint [m]
# Length of a perimeter wall [m]
# Building adjacency
# Mean neighbor distance between buildings [m]
# Length of a street segment [m]
# Linearity of a street segment
# Width of a street profile [m]
# Openness of a street profile
# Meshedness of a street network

# %% [markdown]
# In three cases, `Building adjacency`, `Linearity of a street segment`, and `Width deviation of a street profile`, Mann–Whitney _U_ is not significant (`p < 0.05`) in all pairwise cases.

# %%
mann_whitney_p['Building adjacency'] > .05
# Out:
#                  pre-industrial  industrial  garden city  modernist  \
# pre-industrial             True       False        False       True
# industrial                False        True         True      False
# garden city               False        True         True      False
# modernist                  True       False        False       True
# neo-traditional           False       False        False      False
# informal                  False       False        False      False
#
#                  neo-traditional  informal
# pre-industrial             False     False
# industrial                 False     False
# garden city                False     False
# modernist                  False     False
# neo-traditional             True     False
# informal                   False      True

# %%
mann_whitney_p['Building adjacency'].round(3)
# Out:
#                 pre-industrial industrial garden city modernist  \
# pre-industrial             1.0        0.0         0.0  0.068911
# industrial                 0.0        1.0    0.835986       0.0
# garden city                0.0   0.835986         1.0       0.0
# modernist             0.068911        0.0         0.0       1.0
# neo-traditional            0.0        0.0         0.0       0.0
# informal                   0.0        0.0         0.0       0.0
#
#                 neo-traditional informal
# pre-industrial              0.0      0.0
# industrial                  0.0      0.0
# garden city                 0.0      0.0
# modernist                   0.0      0.0
# neo-traditional             1.0  0.00388
# informal                0.00388      1.0

# %% [markdown]
# In the case of `Building adjacency`, the distributions of values in Garden city and Modernist periods cannot be considered significantly different.

# %%
mann_whitney_p['Linearity of a street segment'] > .05
# Out:
#                  pre-industrial  industrial  garden city  modernist  \
# pre-industrial             True       False        False      False
# industrial                False        True        False      False
# garden city               False       False         True       True
# modernist                 False       False         True       True
# neo-traditional           False       False         True       True
# informal                  False       False        False      False
#
#                  neo-traditional  informal
# pre-industrial             False     False
# industrial                 False     False
# garden city                 True     False
# modernist                   True     False
# neo-traditional             True     False
# informal                   False      True

# %%
mann_whitney_p['Linearity of a street segment'].round(3)
# Out:
#                 pre-industrial industrial garden city modernist  \
# pre-industrial             1.0   0.000015    0.000245  0.004818
# industrial            0.000015        1.0         0.0       0.0
# garden city           0.000245        0.0         1.0  0.219432
# modernist             0.004818        0.0    0.219432       1.0
# neo-traditional       0.009402        0.0    0.291905  0.542148
# informal                   0.0        0.0         0.0       0.0
#
#                 neo-traditional informal
# pre-industrial         0.009402      0.0
# industrial                  0.0      0.0
# garden city            0.291905      0.0
# modernist              0.542148      0.0
# neo-traditional             1.0      0.0
# informal                    0.0      1.0

# %% [markdown]
# In the case of `Linearity of a street segment`, the distributions of values in Garden city and Modernist periods cannot be considered significantly different.

# %%
mann_whitney_p['Width deviation of a street profile [m]'] > .05
# Out:
#                  pre-industrial  industrial  garden city  modernist  \
# pre-industrial             True       False        False      False
# industrial                False        True        False      False
# garden city               False       False         True      False
# modernist                 False       False        False       True
# neo-traditional           False       False        False      False
# informal                  False       False        False      False
#
#                  neo-traditional  informal
# pre-industrial             False     False
# industrial                 False     False
# garden city                False     False
# modernist                  False     False
# neo-traditional             True     False
# informal                   False      True

# %%
mann_whitney_p['Width deviation of a street profile [m]'].round(3)
# Out:
#                 pre-industrial industrial garden city modernist  \
# pre-industrial             1.0        0.0         0.0  0.002552
# industrial                 0.0        1.0         0.0  0.002509
# garden city                0.0        0.0         1.0       0.0
# modernist             0.002552   0.002509         0.0       1.0
# neo-traditional            0.0        0.0    0.003897       0.0
# informal                   0.0    0.00194    0.000001       0.0
#
#                 neo-traditional  informal
# pre-industrial              0.0       0.0
# industrial                  0.0   0.00194
# garden city            0.003897  0.000001
# modernist                   0.0       0.0
# neo-traditional             1.0       0.0
# informal                    0.0       1.0

# %% [markdown]
# In the case of `Width deviation of a street profile`, the distributions of values in Pre-industrial and Modernist periods cannot be considered significantly different.
