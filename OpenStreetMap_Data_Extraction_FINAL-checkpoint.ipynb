# %%
import osmnx as ox
import os
import geopandas as gpd
from pyproj import CRS
import matplotlib.pyplot as plt
proxy = 'http://edcguest:edcguest@172.31.100.27:3128'
os.environ['http_proxy'] = proxy 
os.environ['HTTP_PROXY'] = proxy
os.environ['https_proxy'] = proxy
os.environ['HTTPS_PROXY'] = proxy

# %%
highwaytypeall=['unclassified','trunk_link','trunk','track','tertiary_link','tertiary', 'steps','services','service',
               'secondary_link','secondary','residential','primary_link','primary','pedestrian','path','motorway_link',
               'motorway','living_street','footway','construction']
highwaytypesel=['unclassified','trunk_link','trunk','tertiary_link','tertiary','services','service',
               'secondary_link','secondary','residential','primary_link','primary','motorway_link','motorway','living_street',
               'construction']
landusetags=['university',\
'retail',\
'residential',\
'religious',\
'recreation_ground',\
'railway',\
'prison',\
'military',\
'meadow',\
'industrial',\
'grass',\
'forest',\
'farmyard',\
'farmland',\
'commercial',\
'cemetery',\
'brownfield',\
'basin',\
'aquaculture'
]

# %%
landusetags
# Out:
# ['university',
#  'retail',
#  'residential',
#  'religious',
#  'recreation_ground',
#  'railway',
#  'prison',
#  'military',
#  'meadow',
#  'industrial',
#  'grass',
#  'forest',
#  'farmyard',
#  'farmland',
#  'commercial',
#  'cemetery',
#  'brownfield',
#  'basin',
#  'aquaculture']

# %%
# gdfgeom= ox.geometries.geometries_from_bbox(26.5575769000000008,27.1233809999999984,80.5943689000000063, 81.0814893000000012,\
# tags = {'amenity':True, 'landuse':['retail','commercial'],'building', 'highway':highwaytypesel})

# %%
# gdfgeom.head()

# %%
nameofcity='mumbai,maharastra,India'
epsgtag='epsg:32643'
projcode='32643'

# %%
gdfgeompoly= ox.geometries_from_place(nameofcity,tags = {'landuse':True, 'building':True, 'highway':highwaytypesel})

# %%
gdfgeompoly.head()
# Out:
#                        source                   geometry created_by highway  \
# element_type osmid
# node         245680218    NaN  POINT (72.87390 19.19823)        NaN     NaN
#              296353472    NaN  POINT (72.82166 18.99869)        NaN     NaN
#              621556527    NaN  POINT (72.84305 19.10068)        NaN     NaN
#              622267823    NaN  POINT (72.83027 19.05834)        NaN     NaN
#              705149086    NaN  POINT (72.81763 18.95391)        NaN     NaN
#
#                                                                    fixme  \
# element_type osmid
# node         245680218                                               NaN
#              296353472                                               NaN
#              621556527  landuse not correct here, amenity?, supermarket?
#              622267823                                               NaN
#              705149086                                               NaN
#
# ...

# %%
type(gdfgeompoly['landuse'])
# Out:
# pandas.core.series.Series

# %%
gdfgeompoly.to_file("C:/Users/HP/Desktop/OSMnx Work/OpenStreetMap_Data_Extraction_FINAL/Landuse_OSMNX.gpkg",
                    driver="GPKG",layer="landuse")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# C:\JupyterLab\resources\jlab_server\lib\site-packages\geopandas\io\file.py in _to_file(df, filename, driver, schema, index, mode, crs, **kwargs)
#     395         ) as colxn:
# --> 396             colxn.writerecords(df.iterfeatures())
#     397
#
# C:\JupyterLab\resources\jlab_server\lib\site-packages\fiona\collection.py in writerecords(self, records)
#     360             raise IOError("collection not open for writing")
# --> 361         self.session.writerecs(records, self)
#     362         self._len = self.session.get_length()
#
# fiona/ogrext.pyx in fiona.ogrext.WritingSession.writerecs()
#
# ...

# %%
fpath='C:/Users/HP/Desktop/OSMnx Work/OpenStreetMap_Data_Extraction_FINAL/'

# %%
# gdfgeompoly.to_file(fpath + 'Sample_Bus_Data_LKO_tracts.gpkg', layer='countries', driver="GPKG")

# %%
colarry=list(gdfgeompoly.columns.values)
fcolumns = [sub.replace(':', '_') for sub in colarry]

# %%
# import pandasql as ps 
# import pandas as pd
# slist=dfgeompoly.values.tolist()
# dfgeompoly = pd.DataFrame(slist,columns=fcolumns)

# %%
gdfgeompoly.columns = fcolumns

# %%
fcolumns
# Out:
# ['source',
#  'geometry',
#  'created_by',
#  'highway',
#  'fixme',
#  'noexit',
#  'addr_city',
#  'addr_housenumber',
#  'addr_postcode',
#  'addr_street',
#  'name',
#  'name_en',
#  'name_hi',
#  'office',
#  'place',
#  'amenity',
#  'junction',
#  'barrier',
#  'bus',
#  'public_transport',
#  'tourism',
#  'landuse',
#  'residential',
#  'operator',
#  'name_mr',
#  'direction',
#  'surface',
#  'access',
#  'entrance',
#  'foot',
#  'motor_vehicle',
#  'ele',
#  'railway',
#  'addr_district',
#  'addr_postcode_1',
#  'population',
#  'population_date',
#  'wikipedia',
#  'bicycle',
#  'horse',
#  'motorcar',
#  'motorcycle',
#  'name_zh',
#  'ref',
#  'addr_housename',
#  'building',
#  'consulate',
#  'country',
#  'diplomatic',
#  'name_de',
#  'target',
#  'website',
#  'description',
#  'historic',
#  'int_name',
#  'alt_name',
#  'area',
#  'designation',
#  'religion',
#  'military',
#  'layer',
#  'wheelchair',
#  'building_levels',
#  'shop',
#  'leisure',
# ...

# %%
gdfgeompoly[['geometry', 'landuse']]
# Out:
#                                                                  geometry  \
# element_type osmid
# node         245680218                          POINT (72.87390 19.19823)
#              296353472                          POINT (72.82166 18.99869)
#              621556527                          POINT (72.84305 19.10068)
#              622267823                          POINT (72.83027 19.05834)
#              705149086                          POINT (72.81763 18.95391)
# ...                                                                   ...
# relation     13162506   POLYGON ((72.83490 18.98709, 72.83484 18.98679...
#              13517185   POLYGON ((72.81850 18.91350, 72.81844 18.91343...
#              13536360   POLYGON ((72.91075 19.04916, 72.91088 19.04983...
#              13649674   POLYGON ((72.82150 19.01625, 72.82171 19.01580...
#              14019871   POLYGON ((72.81432 18.90159, 72.81452 18.90151...
#
#                             landuse
# element_type osmid
# ...

# %%
gdfgeompoly.name.replace({r'[^\x00-\x7F]+':''}, regex=True, inplace=True)
gdfgeompoly.fillna('', inplace=True)
# Out:
# C:\JupyterLab\resources\jlab_server\lib\site-packages\pandas\core\generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
datapolygon= []
idx=0
slist=[]
for index, ref in gdfgeompoly.iterrows(): 
 if ref['geometry'].geom_type=='Polygon' and ref['landuse']!='':
     idx=idx+1  
     slist=[idx,ref["geometry"],ref["landuse"]]
     datapolygon.append(slist)

# %%
polycols=['ROWINDEX','geometry','landuse']

# %%
geodatapolygon = gpd.GeoDataFrame(datapolygon, columns=polycols, crs = CRS.from_epsg('4326'))

# %%
geodatapolygon.head()
# Out:
#    ROWINDEX                                           geometry  \
# 0         1  POLYGON ((72.82269 18.99655, 72.82302 18.99574...
# 1         2  POLYGON ((72.82117 18.99957, 72.82183 18.99960...
# 2         3  POLYGON ((72.84234 19.11510, 72.84235 19.11552...
# 3         4  POLYGON ((72.81234 19.13427, 72.81299 19.13460...
# 4         5  POLYGON ((72.81305 19.13517, 72.81314 19.13504...
#
#              landuse
# 0         commercial
# 1         commercial
# 2             retail
# 3  recreation_ground
# 4        residential

# %%
# import itertools
# geoms = geodatapolygon['geometry'].tolist()
# cleaned_polygon = gpd.GeoDataFrame(gpd.GeoSeries([poly[0].intersection(poly[1]) for poly in  itertools.combinations(geoms, 2) if poly[0].intersects(poly[1])]), columns=['geometry'])
# cleaned_polygon.to_file(fpath + 'Lucknow_Landuse_Cleaned.gpkg', layer='landuse', driver="GPKG")

# %%
geodatapolygon.plot(geodatapolygon['landuse'], figsize=(20,25),legend = True)
# Out:
# <AxesSubplot:>

# %%
geodatapolygon_UTM  = geodatapolygon.to_crs({'init': epsgtag})
geodatapolygon_UTM.to_file(fpath + nameofcity + '_Landuse.gpkg', layer='landuse', driver="GPKG")
# Out:
# C:\JupyterLab\resources\jlab_server\lib\site-packages\pyproj\crs\crs.py:131: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %%
dataroads= []
idx=0
slist=[]
for index, ref in gdfgeompoly.iterrows(): 
 if ref['geometry'].geom_type=='LineString':
     idx=idx+1
     slist=[idx,ref["geometry"],ref["highway"]]
     dataroads.append(slist)

# %%
roadscols=['ROWINDEX','geometry','highway']

# %%
geodataroads = gpd.GeoDataFrame(dataroads, columns=roadscols, crs = CRS.from_epsg('4326'))
geodataroads_UTM  = geodataroads.to_crs({'init': epsgtag})
geodataroads_UTM.to_file(fpath + nameofcity + '_Landuse.gpkg', layer='roads', driver="GPKG")
# Out:
# C:\JupyterLab\resources\jlab_server\lib\site-packages\pyproj\crs\crs.py:131: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %%
databuilding= []
idx=0
slist=[]
for index, ref in gdfgeompoly.iterrows(): 
 if ref['geometry'].geom_type=='Polygon' and ref['building']!='':
     idx=idx+1 
     slist=[idx,ref["geometry"],ref["building"]]       
     databuilding.append(slist)

# %%
buildingcols=['ROWINDEX','geometry','building']

# %%
geodatabuildings = gpd.GeoDataFrame(databuilding, columns=buildingcols, crs = CRS.from_epsg('4326'))
geodatabuildings_UTM  = geodatabuildings.to_crs({'init': epsgtag})
geodatabuildings_UTM.to_file(fpath + nameofcity + '_Landuse.gpkg', layer='buildings', driver="GPKG")
# Out:
# C:\JupyterLab\resources\jlab_server\lib\site-packages\pyproj\crs\crs.py:131: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %%
geodatapolygon_UTM.head()
# Out:
#    ROWINDEX                                           geometry  \
# 0         1  POLYGON ((270790.097 2101864.229, 270823.317 2...
# 1         2  POLYGON ((270634.079 2102199.740, 270703.173 2...
# 2         3  POLYGON ((273020.267 2114963.344, 273022.486 2...
# 3         4  POLYGON ((269890.597 2117124.782, 269959.348 2...
# 4         5  POLYGON ((269966.597 2117223.510, 269975.608 2...
#
#              landuse
# 0         commercial
# 1         commercial
# 2             retail
# 3  recreation_ground
# 4        residential

# %%
# gdfgeompoly_c=gdfgeompoly.copy(deep=False)
# gdfgeompoly_c['geometry']=gdfgeompoly_c['geometry'].astype(str)
# dfgeompoly=gdfgeompoly[gdfgeompoly_c["geometry"].str.contains("POLYGON")]
# dfgeompoly.to_csv(fpath + 'LKO_Landuse_Poly.csv')

# %%
# gdfgeompoly_c1=gdfgeompoly.copy(deep=False)
# gdfgeompoly_c1['geometry']=gdfgeompoly_c1['geometry'].astype(str)
# dfgeomline=gdfgeompoly[gdfgeompoly_c1["geometry"].str.contains("LINESTRING")]
# dfgeomline.to_csv(fpath + 'LKO_Roads.csv')

# %%
import pandas as pd
errorflag=0
data_temp=geodatapolygon_UTM.copy(deep=False)
data_temp['id']= data_temp['ROWINDEX'].astype(str)
data_overlaps=gpd.GeoDataFrame(crs=data_temp.crs)
try:
 for index, row in data_temp.iterrows():
     data_temp1=data_temp.loc[data_temp.id!=row.id,]
    # check if intersection occured
     overlaps=data_temp1[data_temp1.geometry.overlaps(row.geometry)]['id'].tolist()
     if len(overlaps)>0:
         temp_list=[]
        # compare the area with threshold
         for y in overlaps:
             temp_area=gpd.overlay(data_temp.loc[data_temp.id==y,],data_temp.loc[data_temp.id==row.id,],how='intersection')
             temp_area=temp_area.loc[temp_area.geometry.area>=9e-9]
             if temp_area.shape[0]>0:
                 data_overlaps=gpd.GeoDataFrame(pd.concat([temp_area,data_overlaps],ignore_index=True),crs=data_temp.crs)
# get unique of list id
 data_overlaps['sorted']=data_overlaps.apply(lambda y: sorted([y['id_1'],y['id_2']]),axis=1)
 data_overlaps['sorted']=data_overlaps.sorted.apply(lambda y: ''.join(y))
 data_overlaps=data_overlaps.drop_duplicates('sorted')
 data_overlaps=data_overlaps.reset_index()[['id_1','id_2','geometry']]
except ValueError:
 print("Oops!  That was no valid number.  Try again...")
 errorflag=1
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_12696/2809086413.py:5: FutureWarning: Assigning CRS to a GeoDataFrame without a geometry column is now deprecated and will not be supported in the future.
#   data_overlaps=gpd.GeoDataFrame(crs=data_temp.crs)
# C:\Users\HP\AppData\Local\Temp/ipykernel_12696/2809086413.py:15: UserWarning: `keep_geom_type=True` in overlay resulted in 2 dropped geometries of different geometry types than df1 has. Set `keep_geom_type=False` to retain all geometries
#   temp_area=gpd.overlay(data_temp.loc[data_temp.id==y,],data_temp.loc[data_temp.id==row.id,],how='intersection')
# C:\Users\HP\AppData\Local\Temp/ipykernel_12696/2809086413.py:15: UserWarning: `keep_geom_type=True` in overlay resulted in 1 dropped geometries of different geometry types than df1 has. Set `keep_geom_type=False` to retain all geometries
#   temp_area=gpd.overlay(data_temp.loc[data_temp.id==y,],data_temp.loc[data_temp.id==row.id,],how='intersection')
# ...

# %%
if (errorflag==0):
 data_overlaps.to_file(fpath + nameofcity + '_Landuse.gpkg', layer='landuse_overlaps', driver="GPKG")

# %%
fpath
# Out:
# 'C:/Users/HP/Desktop/OSMnx Work/OpenStreetMap_Data_Extraction_FINAL/'

# %%
spoly = gpd.GeoSeries(data_temp['geometry'], crs=epsgtag)

# %%
# from itertools import combinations
# for p1_idx, p2_idx in combinations(spoly.index, 2):
#     if spoly.loc[p1_idx].intersects(spoly.loc[p2_idx]):
#         # Store intermediary results back to poly
#         spoly.loc[p2_idx] -= spoly.loc[p1_idx]

# %%
df1=geodatapolygon_UTM.copy(deep=False)
df1.reset_index(drop=True)
# df2=geodatapolygon_UTM.copy(deep=False)
# df2.reset_index(drop=True)
# Out:
#       ROWINDEX                                           geometry  \
# 0            1  POLYGON ((270790.097 2101864.229, 270823.317 2...
# 1            2  POLYGON ((270634.079 2102199.740, 270703.173 2...
# 2            3  POLYGON ((273020.267 2114963.344, 273022.486 2...
# 3            4  POLYGON ((269890.597 2117124.782, 269959.348 2...
# 4            5  POLYGON ((269966.597 2117223.510, 269975.608 2...
# ...        ...                                                ...
# 2989      2990  POLYGON ((276912.606 2115898.045, 276602.915 2...
# 2990      2991  POLYGON ((276912.606 2115898.045, 276690.946 2...
# 2991      2992  POLYGON ((271617.220 2097979.662, 271647.779 2...
# 2992      2993  POLYGON ((271684.641 2108697.548, 271612.294 2...
# 2993      2994  POLYGON ((281722.965 2113387.255, 282077.769 2...
#
#                 landuse
# 0            commercial
# 1            commercial
# 2                retail
# 3     recreation_ground
# 4           residential
# ...

# %%
# data_temp_1 = df1.loc[~df1.intersects(df2.unary_union)].reset_index(drop=True)

# %%
res_symdiff = df1.overlay(data_overlaps, how='symmetric_difference')
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12696/3757888868.py in <module>
# ----> 1 res_symdiff = df1.overlay(data_overlaps, how='symmetric_difference')
#
# C:\JupyterLab\resources\jlab_server\lib\site-packages\geopandas\geodataframe.py in overlay(self, right, how, keep_geom_type, make_valid)
#    2194         dimension is not taken into account.
#    2195         """
# -> 2196         return geopandas.overlay(
#    2197             self, right, how=how, keep_geom_type=keep_geom_type, make_valid=make_valid
#    2198         )
#
# C:\JupyterLab\resources\jlab_server\lib\site-packages\geopandas\tools\overlay.py in overlay(df1, df2, how, keep_geom_type, make_valid)
#     311             result = _overlay_intersection(df1, df2)
#     312         elif how == "symmetric_difference":
# --> 313             result = _overlay_symmetric_diff(df1, df2)
# ...

# %%
res_symdiff.reset_index(drop=True)
# Out:
#      id_1  id_2                                           geometry
# 0    2437  2991  POLYGON ((276426.247 2116230.970, 276263.458 2...
# 1    2114  2989  POLYGON ((275612.453 2118943.503, 275602.749 2...
# 2    2087  2989  POLYGON ((276487.442 2120690.163, 276479.253 2...
# 3    2083  2989  POLYGON ((276257.789 2120695.776, 276256.482 2...
# 4    2079  2989  MULTIPOLYGON (((277506.551 2119552.235, 277481...
# ..    ...   ...                                                ...
# 166   115   311  POLYGON ((274145.041 2118932.285, 274158.660 2...
# 167   275   278  POLYGON ((270100.175 2122934.886, 270093.405 2...
# 168     1   157  POLYGON ((270823.317 2101773.895, 270822.857 2...
# 169   138   141  POLYGON ((272266.856 2100318.078, 272287.202 2...
# 170    26    27  POLYGON ((269826.287 2101120.764, 269826.077 2...
#
# [171 rows x 3 columns]

# %%
res_symdiff=res_symdiff.drop(['id_1','id_2','ROWINDEX'], axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12696/2479332711.py in <module>
# ----> 1 res_symdiff=res_symdiff.drop(['id_1','id_2','ROWINDEX'], axis = 1)
#
# C:\JupyterLab\resources\jlab_server\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# C:\JupyterLab\resources\jlab_server\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ...

# %%
res_symdiff.fillna('mixed', inplace=True)

# %%
res_symdiff
# Out:
#                                               geometry
# 0    POLYGON ((276426.247 2116230.970, 276263.458 2...
# 1    POLYGON ((275612.453 2118943.503, 275602.749 2...
# 2    POLYGON ((276487.442 2120690.163, 276479.253 2...
# 3    POLYGON ((276257.789 2120695.776, 276256.482 2...
# 4    MULTIPOLYGON (((277506.551 2119552.235, 277481...
# ..                                                 ...
# 166  POLYGON ((274145.041 2118932.285, 274158.660 2...
# 167  POLYGON ((270100.175 2122934.886, 270093.405 2...
# 168  POLYGON ((270823.317 2101773.895, 270822.857 2...
# 169  POLYGON ((272266.856 2100318.078, 272287.202 2...
# 170  POLYGON ((269826.287 2101120.764, 269826.077 2...
#
# [171 rows x 1 columns]

# %%
data_overlaps_c= data_overlaps.copy(deep=False).explode()
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_12696/970361620.py:1: FutureWarning: Currently, index_parts defaults to True, but in the future, it will default to False to be consistent with Pandas. Use `index_parts=True` to keep the current behavior and True/False to silence the warning.
#   data_overlaps_c= data_overlaps.copy(deep=False).explode()

# %%
data_overlaps_c['landuse']='mixed'

# %%
data_overlaps_c.head()
# Out:
#      id_1  id_2                                           geometry landuse
# 0 0  2437  2991  POLYGON ((276426.247 2116230.970, 276263.458 2...   mixed
# 1 0  2114  2989  POLYGON ((275612.453 2118943.503, 275602.749 2...   mixed
# 2 0  2087  2989  POLYGON ((276487.442 2120690.163, 276479.253 2...   mixed
# 3 0  2083  2989  POLYGON ((276257.789 2120695.776, 276256.482 2...   mixed
# 4 0  2079  2989  POLYGON ((277506.551 2119552.235, 277481.565 2...   mixed

# %%
data_overlaps_c.reset_index(drop=True)
# Out:
#      id_1  id_2                                           geometry landuse
# 0    2437  2991  POLYGON ((276426.247 2116230.970, 276263.458 2...   mixed
# 1    2114  2989  POLYGON ((275612.453 2118943.503, 275602.749 2...   mixed
# 2    2087  2989  POLYGON ((276487.442 2120690.163, 276479.253 2...   mixed
# 3    2083  2989  POLYGON ((276257.789 2120695.776, 276256.482 2...   mixed
# 4    2079  2989  POLYGON ((277506.551 2119552.235, 277481.565 2...   mixed
# ..    ...   ...                                                ...     ...
# 186   115   311  POLYGON ((274145.041 2118932.285, 274158.660 2...   mixed
# 187   275   278  POLYGON ((270100.175 2122934.886, 270093.405 2...   mixed
# 188     1   157  POLYGON ((270823.317 2101773.895, 270822.857 2...   mixed
# 189   138   141  POLYGON ((272266.856 2100318.078, 272287.202 2...   mixed
# 190    26    27  POLYGON ((269826.287 2101120.764, 269826.077 2...   mixed
#
# [191 rows x 4 columns]

# %%
data_overlaps_c=data_overlaps_c.drop(['id_1','id_2'], axis = 1)

# %%
data_overlaps_c.head()
# Out:
#                                               geometry landuse
# 0 0  POLYGON ((276426.247 2116230.970, 276263.458 2...   mixed
# 1 0  POLYGON ((275612.453 2118943.503, 275602.749 2...   mixed
# 2 0  POLYGON ((276487.442 2120690.163, 276479.253 2...   mixed
# 3 0  POLYGON ((276257.789 2120695.776, 276256.482 2...   mixed
# 4 0  POLYGON ((277506.551 2119552.235, 277481.565 2...   mixed

# %%
data_overlaps_c.reset_index(drop=True)
# Out:
#                                               geometry landuse
# 0    POLYGON ((276426.247 2116230.970, 276263.458 2...   mixed
# 1    POLYGON ((275612.453 2118943.503, 275602.749 2...   mixed
# 2    POLYGON ((276487.442 2120690.163, 276479.253 2...   mixed
# 3    POLYGON ((276257.789 2120695.776, 276256.482 2...   mixed
# 4    POLYGON ((277506.551 2119552.235, 277481.565 2...   mixed
# ..                                                 ...     ...
# 186  POLYGON ((274145.041 2118932.285, 274158.660 2...   mixed
# 187  POLYGON ((270100.175 2122934.886, 270093.405 2...   mixed
# 188  POLYGON ((270823.317 2101773.895, 270822.857 2...   mixed
# 189  POLYGON ((272266.856 2100318.078, 272287.202 2...   mixed
# 190  POLYGON ((269826.287 2101120.764, 269826.077 2...   mixed
#
# [191 rows x 2 columns]

# %%
res_union = res_symdiff.overlay(data_overlaps_c, how='union')
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12696/4252826823.py in <module>
# ----> 1 res_union = res_symdiff.overlay(data_overlaps_c, how='union')
#
# C:\JupyterLab\resources\jlab_server\lib\site-packages\geopandas\geodataframe.py in overlay(self, right, how, keep_geom_type, make_valid)
#    2194         dimension is not taken into account.
#    2195         """
# -> 2196         return geopandas.overlay(
#    2197             self, right, how=how, keep_geom_type=keep_geom_type, make_valid=make_valid
#    2198         )
#
# C:\JupyterLab\resources\jlab_server\lib\site-packages\geopandas\tools\overlay.py in overlay(df1, df2, how, keep_geom_type, make_valid)
#     313             result = _overlay_symmetric_diff(df1, df2)
#     314         elif how == "union":
# --> 315             result = _overlay_union(df1, df2)
# ...

# %%
res_union
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12696/2588313471.py in <module>
# ----> 1 res_union
#
# NameError: name 'res_union' is not defined

# %%
res_union.reset_index(drop=True)

# %%
res_union.fillna('', inplace=True)

# %%
res_union['landuse']=res_union['landuse_1']+ " " + res_union['landuse_2']

# %%
res_union=res_union.drop(['landuse_1','landuse_2'], axis = 1)

# %%
res_union['row_index']=res_union.index.astype(int)
res_union["area"] = res_union['geometry'].area

# %%
polygons_small = res_union.sjoin(res_union, how="inner", predicate='within')

# %%
polygons_small

# %%
polysmall=polygons_small[((polygons_small['row_index_left'] != polygons_small['row_index_right']) &
                          (polygons_small['landuse_right'] == polygons_small['landuse_left']) &
                          (polygons_small['area_left'] < polygons_small['area_right']) )]

# %%
polysmall

# %%
polysmall['landuse']=polysmall['landuse_left']
polysmall=polysmall.drop(['area_left','landuse_left','landuse_right','row_index_right','area_right','index_right'], axis = 1)

# %%
polysmall

# %%
dropindexlist=polysmall['row_index_left'].to_list()

# %%
dropindexlist

# %%
res_union.head()

# %%
res_union1= res_union[~res_union['row_index'].isin(dropindexlist)]

# %%
res_union1["geometry"] = res_union1["geometry"].apply(lambda geom: geom.wkb)
res_union1.drop_duplicates(["geometry"])
res_union1["geometry"] = res_union1["geometry"].apply(lambda geom: shapely.wkb.loads(geom))

# %%
mask = res_union1.area >0.0  # metres squared

# %%
res_union2 = res_union1.loc[mask]

# %%
import numpy as np
centroids = np.vstack([res_union2.centroid.x, res_union2.centroid.y]).T

# %%
res_union2.loc.__setitem__((slice(None), ('CEN_X')), res_union2.centroid.x)
res_union2.loc.__setitem__((slice(None), ('CEN_Y')), res_union2.centroid.y)

# %%
res_union2

# %%
# temp_df2= res_union1[['geomstr', 'row_index']]

# %%
# import pandasql as ps 
# q1 = """SELECT row_index FROM temp_df2 GROUP BY geomstr HAVING COUNT(*)>1"""
# dfsample=pd.DataFrame()
# dfsample=ps.sqldf(q1, locals())
# dupgeomindex=dfsample['row_index'].tolist()

# %%
# res_union3= res_union1[~res_union1['row_index'].isin(dupgeomindex)]

# %%
res_union2.to_file(fpath + nameofcity + '_Landuse.gpkg', layer='filtered_polygon', driver="GPKG")

# %%
# import itertools
# geoms = data_temp['geometry'].tolist()
# intersection_iter = gpd.GeoDataFrame(gpd.GeoSeries([poly[0].intersection(poly[1]) 
#                     for poly in  itertools.combinations(geoms, 2) 
#                     if poly[0].intersects(poly[1])]), columns=['geometry'])

# %%
# polygon_landuse=geodatapolygon_UTM.to_wkb(hex=False, byte_order=1)

# %%
G = ox.graph_from_place(nameofcity,network_type='drive')
#ox.plot_graph(G)
#ox.io.save_graph_shapefile(G, filepath='D:\QGIS_Data\FinalPT\DEL_Roads')
G_projected = ox.project_graph(G)
#ox.io.save_graph_shapefile(G_projected, filepath='D:\QGIS_Data\FinalPT\DEL_Roads')

# %%
gdf_nodes, gdf_edges = ox.graph_to_gdfs(
        G_projected,
        nodes=True, edges=True,
        node_geometry=True,
        fill_edge_geometry=True)

# %%
gdf_edges.head()

# %%
list(gdf_edges.columns.values)

# %%
gdf_edges.name.replace({r'[^\x00-\x7F]+':''}, regex=True, inplace=True)
gdf_edges.fillna('', inplace=True)

# %%
# collist=['osmid', 'highway', 'oneway', 'length', 'geometry', 'name', 'access', 'lanes', 'bridge', 
#          'junction', 'maxspeed', 'width', 'area', 'tunnel','service']
collist=['osmid', 'highway', 'oneway', 'length', 'geometry', 'name']
gdf_edges_U=gdf_edges[collist].copy()

# %%
gdf_edges_U = gdf_edges_U.reset_index()  
gdf_edges_U['u']=gdf_edges_U['u'].astype(str)
gdf_edges_U['v']=gdf_edges_U['v'].astype(str)
gdf_edges_U['key']=gdf_edges_U['key'].astype(int)
gdf_edges_U['osmid']=gdf_edges_U['osmid'].astype(str)
gdf_edges_U['highway']=gdf_edges_U['highway'].astype(str)
gdf_edges_U['oneway']=gdf_edges_U['oneway'].astype(int)
gdf_edges_U['length']=gdf_edges_U['length'].astype(float)
gdf_edges_U['name']=gdf_edges_U['name'].astype(str)
# gdf_edges_U['bridge']=gdf_edges_U['bridge'].astype(str)
# gdf_edges_U['access']=gdf_edges_U['access'].astype(str)
# gdf_edges_U['maxspeed']=gdf_edges_U['maxspeed'].astype(str)
# gdf_edges_U['width']=gdf_edges_U['width'].astype(str)
# gdf_edges_U['area']=gdf_edges_U['area'].astype(str)
# gdf_edges_U['tunnel']=gdf_edges_U['tunnel'].astype(str)
# gdf_edges_U['service']=gdf_edges_U['service'].astype(str)
gdf_edges_U.head()

# %%
gdf_edges_U.to_file(fpath + nameofcity + '_Landuse.gpkg', layer='Graph_Edges', driver="GPKG")

# %%
list(gdf_nodes.columns.values)
